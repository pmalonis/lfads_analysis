# %%
#loading data
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '/home/pmalonis/lfads_analysis/src')
import importlib
import segment_submovements as ss
import timing_analysis as ta
import kinematics_and_input as ki
import utils
import pandas as pd
import h5py
from scipy import io
importlib.reload(utils)
importlib.reload(ss)
importlib.reload(ta)
importlib.reload(ki)

trial_type = 'all'

lfads_filename = "/home/pmalonis/lfads_analysis/data/model_output/rockstar_8QTVEk_%s.h5"%trial_type
data_filename = "/home/pmalonis/lfads_analysis/data/intermediate/rockstar.p"
inputInfo_filename = "/home/pmalonis/lfads_analysis/data/model_output/rockstar_inputInfo.mat"

df = pd.read_pickle(data_filename)
input_info = io.loadmat(inputInfo_filename)
with h5py.File(lfads_filename, 'r') as h5file:
    co = h5file[('controller_outputs')]
    dt = utils.get_dt(h5file, input_info)
    
used_inds = utils.get_indices(input_info, trial_type)
# Out:
# /home/pmalonis/lfads_analysis/src/timing_analysis.py:16: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   with h5py.File(lfads_filename) as h5file:
# /home/pmalonis/lfads_analysis/src/timing_analysis.py:17: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   co = h5file['controller_outputs'].value

# %%
import matplotlib as mpl
mpl.rcParams['figure.max_open_warning'] = False
for i in range(100, 400, 10):
    plt.figure()
    ss.plot_trajectory_co(df.loc[i], co[i,:,0], dt)
